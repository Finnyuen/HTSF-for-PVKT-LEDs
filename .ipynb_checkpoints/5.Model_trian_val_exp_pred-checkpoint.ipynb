# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.model_selection import cross_val_score,learning_curve
from sklearn.metrics import mean_absolute_error as MAE,root_mean_squared_error as RMSE,r2_score as R2,make_scorer

pd.set_option('display.max_rows',300)
pd.set_option('display.max_column',20)

# %% [markdown]
# #### 1.Dataset import

# %%
np.random.seed(42)
#X_train import and split to X_train and X_val(named as X_features)
X_features = pd.read_csv("data/X_features.csv")
y_target = pd.read_csv("data/y_target.csv")
print("X_features shape:",X_features.shape)
print("y_target shape:",y_target.shape)

#import independent dataset
X_independent_test = pd.read_csv("data/X_independent_test.csv")
y_independent_test = pd.read_csv("data/y_independent_test.csv")
print("X_independent_test shape:",X_independent_test.shape)
print("y_independent_test shape:",y_independent_test.shape)

#X_features_copy combined with X_features
X_features_copy = X_features.copy()
X_combined = pd.concat([X_features,X_features_copy],ignore_index=True)

#add guassian noise to y_target
noise = np.random.normal(0,0.2,y_target.shape)#average value eaqual to 0;
y_target_with_noise = y_target + noise
y_combined = pd.concat([y_target,y_target_with_noise])


#X minmax scaler for X_combined and X_independent_test
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler()
X_combined_norm = X_scaler.fit_transform(X_combined)
X_independent_test_norm = X_scaler.fit_transform(X_independent_test)
# Out:
# X_features shape: (110, 12)
# y_target shape: (110, 1)
# X_independent_test shape: (13, 12)
# y_independent_test shape: (13, 1)

# %%
#X_combined_norm res
X_combined_norm = pd.DataFrame(X_combined_norm,columns=X_combined.columns)
X_combined_norm.head()
# Out:
#    A_site  Conc(mg/ml)  H_Acceptors  H_Donors  Rot_bonds    Mol_Wt      TPSA  \
# 0     0.0     0.259175     0.000000      0.00   0.153846  0.190302  0.000000
# 1     0.0     0.013384     0.111111      0.00   0.192308  0.201861  0.051144
# 2     0.0     0.028786     0.111111      0.00   0.076923  0.172869  0.099094
# 3     0.0     0.031359     0.222222      0.25   0.115385  0.192718  0.216533
# 4     1.0     0.096356     0.444444      0.00   0.192308  0.274529  0.383200
#
#      AvgIpc  Hydrogen     Oxide  Nitrogen  Halide
# 0  0.664815  0.250000  0.000000  0.166667     0.2
# 1  0.752115  0.267857  0.000000  0.333333     0.8
# 2  0.723895  0.178571  0.111111  0.000000     0.0
# 3  0.742535  0.196429  0.222222  0.000000     0.0
# 4  0.777060  0.267857  0.333333  0.333333     0.6

# %%
#y_res
y_combined.head()
# Out:
#    EQE enhanced ratio
# 0              2.7368
# 1              1.6098
# 2              1.1568
# 3              1.1811
# 4              1.9079

# %%
X_independent_test_norm = pd.DataFrame(X_independent_test_norm,columns=X_independent_test.columns)
X_independent_test_norm.head()
# Out:
#    A_site  Conc(mg/ml)  H_Acceptors  H_Donors  Rot_bonds    Mol_Wt      TPSA  \
# 0     1.0     0.000000     0.500000  1.000000   0.071429  0.025851  0.969849
# 1     1.0     0.095114     0.500000  0.666667   0.357143  0.036818  0.704495
# 2     0.0     0.396742     0.000000  0.000000   0.357143  0.120105  0.000000
# 3     0.0     0.225814     0.166667  0.333333   0.214286  0.200849  0.289497
# 4     0.0     0.497285     0.000000  0.000000   0.285714  0.157069  0.000000
#
#      AvgIpc  Hydrogen     Oxide  Nitrogen  Halide
# 0  0.663011  0.095238  0.333333  0.666667     0.0
# 1  0.788467  0.261905  0.333333  0.333333     0.0
# 2  0.836026  0.380952  0.000000  0.333333     0.2
# 3  0.923200  0.333333  0.000000  0.333333     0.2
# 4  0.824010  0.333333  0.000000  0.333333     0.2

# %%
X_combined_norm.shape,y_combined.shape
# Out:
# ((220, 12), (220, 1))

# %%
np.random.seed(42)
#Splitting training and test sets
n_bins = 5
y_bins = pd.qcut(y_combined.values.ravel(), n_bins, labels=False)
X_train, X_val, y_train, y_val = train_test_split(X_combined_norm, y_combined.values.ravel(), test_size= 0.2,stratify = y_bins,random_state = 42)

# %% [markdown]
# #### 2.Function defination

# %%
#model trainning and evaluation function

def parity_plot(y_train_pred, y_val_pred,y_independent_test_pred,y_1 = y_train, y_2 = y_val,y_3 = y_independent_test,model_name_s =''):
  
    #Figuresize
    plt.figure(figsize=(6,6))
 
    #Training set
    plt.scatter(y_1, y_train_pred, c ='#AFAFAF', label='Training set', marker="o",s = 120,zorder = 2,alpha = 0.8,edgecolors='w')#s=40
    
    #Validation set
    plt.scatter(y_2, y_val_pred, c ='#E89494', label='Validation set', marker="o",zorder = 2,s=120,alpha = 0.8,edgecolors='w')
    
    #Independent test set
    plt.scatter(y_3, y_independent_test_pred, c ='#56698F', label='Inde_test set', marker="o",s=120,zorder = 2,alpha=0.8,edgecolors='w')
    
    #Background grids
    plt.grid(True, color='#eaeaea')
    
    #reference line
    plt.plot([-1,7], [-1, 7], '--', lw = 2,label = 'reference', c ='#eaeaea',alpha=0.8,zorder = 1)
    
    plt.title(f'Performance of {model_name_s}',fontsize = 20,fontstyle ='italic',loc = 'center')
    plt.xlim(-1, 7)
    plt.ylim(-1, 7)
    plt.xticks(fontsize = 18)
    plt.yticks(fontsize = 18)
    plt.xlabel('Observations',fontsize = 20)
    plt.ylabel('Predictions',fontsize = 20)
    plt.legend(loc="upper left",fontsize = 18)
    
    plt.rcParams['xtick.direction'] = 'in'
    plt.rcParams['ytick.direction'] = 'in'
    
    plt.savefig(f"output_figures/performance_{model_name_s}.png",dpi = 600)
    return plt.show()

def evaluator(y_train_pred,y_val_pred,y_independent_test_pred):
    #Training set
    rmse_train = RMSE(y_train,y_train_pred)
    mse_train = rmse_train ** 2
    mae_train = MAE(y_train, y_train_pred)
    r2_train = R2(y_train,y_train_pred)
    
    #Validation set
    rmse_val = RMSE(y_val, y_val_pred)
    mse_val = rmse_val ** 2
    mae_val = MAE(y_val, y_val_pred)
    r2_val = R2(y_val,y_val_pred)
    
    #Independent test set
    rmse_test = RMSE(y_independent_test, y_independent_test_pred)
    mse_test = rmse_test ** 2
    
    mae_test = MAE(y_independent_test, y_independent_test_pred)
    r2_test = R2(y_independent_test,y_independent_test_pred)
    

    eval_res = pd.DataFrame({
        "Evaluation criterion":["MSE","RMSE","MAE","R2_Score"],
        "Training Data": [mse_train,rmse_train,mae_train,r2_train],
        "validtation Data": [mse_val,rmse_val,mae_val,r2_val],
        'independent test Data':[mse_test,rmse_test,mae_test,r2_test]
    })
    
    return eval_res

def model_builder(model_name):
    #trainning model
    model_name.fit(X_train, y_train)
    
    y_train_pred = model_name.predict(X_train)
    
    y_val_pred = model_name.predict(X_val)
    
    y_independent_test_pred = []
    y_independent_test_pred = model_name.predict(X_independent_test_norm)
    
    model_name_s = type(model_name).__name__
    
    parity_plot(y_train_pred,y_val_pred,y_independent_test_pred,model_name_s = model_name_s)
    
    eval_res = evaluator(y_train_pred,y_val_pred,y_independent_test_pred)
    
    return eval_res,y_val_pred

 #Model cross validation
def cv_score_calculor(model_name,fold = 5):
   
    X = X_train
    y = y_train
    score_ave_negMSE_train = cross_val_score(model_name,X,y,cv=fold,scoring='neg_mean_squared_error',n_jobs = -1).mean()
    score_ave_negRMSE_train = cross_val_score(model_name,X,y,cv = fold,scoring='neg_root_mean_squared_error',n_jobs = -1).mean()
    score_ave_negMAE_train = cross_val_score(model_name,X,y,cv = fold,scoring='neg_mean_absolute_error',n_jobs = -1).mean()
    score_ave_default_train = cross_val_score(model_name,X,y,cv = fold,scoring=None,n_jobs = -1).mean()
    
    cv_res = pd.DataFrame({
        "Score type":["trainset_neg_MSE","trainset_neg_RMSE","train_neg_MAE","train_defalut_score"],
        "CV score on average": [score_ave_negMSE_train,score_ave_negRMSE_train,score_ave_negMAE_train, score_ave_default_train],
    })
    
    return cv_res


def learning_curve_plot(model_name,fold = 5,y_lim = 1,model_name_s =''):
    train_sizes, train_scores, test_scores = learning_curve (
        model_name, X_combined_norm, y_combined, cv = fold,
        scoring = make_scorer(MAE, greater_is_better=False),
        train_sizes=np.linspace(0.1, 1.0, 20), n_jobs=-1)

    train_scores_mean = -np.mean(train_scores, axis=1)
    train_scores_std = -np.std(train_scores, axis=1)
    test_scores_mean = -np.mean(test_scores, axis=1)
    test_scores_std = -np.std(test_scores, axis = 1)


    plt.figure(figsize=(6,6))
  
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, 
                            alpha=0.1, color="#AFAFAF")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, 
                            alpha=0.1, color="#E89494")
    
    plt.plot(train_sizes, train_scores_mean, 'o-', color="#AFAFAF", label=r"score of training set",alpha = 0.8,markersize = 8)
    plt.plot(train_sizes, test_scores_mean, 'o-', color="#E89494", label=r"score of validation set",alpha = 0.8,markersize = 8)

    plt.ylim(0,y_lim)
    plt.xticks(fontsize = 18)
    plt.yticks(fontsize = 18)
    plt.rcParams['xtick.direction'] = 'in'
    plt.rcParams['ytick.direction'] = 'in'
    plt.xlabel('Sample count',fontsize = 20)
    plt.ylabel('MSE',fontsize = 20)
    plt.title(f'Learning curve of {model_name_s}',fontsize = 20,fontstyle ='italic',loc = 'center')
    plt.legend(loc = "upper right",fontsize = 18)
    
    plt.savefig(f"output_figures/LC_{model_name_s}.png",dpi = 600)
   
    return  plt.show()

# %% [markdown]
# #### 3.Model trainning

# %% [markdown]
# ##### 3.1 linear reg

# %%
#Simple linearReg without gridsearch (simple LR reg)
from sklearn.linear_model import  LinearRegression
lr_reg = LinearRegression()
#5-fold cross validation
cv_score_calculor(lr_reg)
# Out:
#             Score type  CV score on average
# 0     trainset_neg_MSE            -0.688005
# 1    trainset_neg_RMSE            -0.822486
# 2        train_neg_MAE            -0.645964
# 3  train_defalut_score             0.061957

# %%
#Plot learning curve
lc_lr = learning_curve_plot(lr_reg,y_lim=1.6,model_name_s= type(lr_reg).__name__)
lc_lr

# %%
#Model fit and independent test prediction
lr_metrics,y_val_pred = model_builder(lr_reg)
lr_metrics
# Out:
#   Evaluation criterion  Training Data  validtation Data  independent test Data
# 0                  MSE       0.570254          0.584853               2.020542
# 1                 RMSE       0.755152          0.764757               1.421458
# 2                  MAE       0.589186          0.625144               1.283373
# 3             R2_Score       0.394533          0.375116              -2.721596

# %%
validation_mse_list = []
validation_rmse_list = []
validation_mae_list =[]
for i in range(20):
    
    X_train_n, X_validation_n, y_train_n, y_validation_n = train_test_split(X_combined_norm, y_combined.values.ravel(), test_size=0.2)
    lr_reg.fit(X_train_n,y_train_n)
    
    y_validation_pred_n = lr_reg.predict(X_validation_n)
    validation_rmse = RMSE(y_validation_pred_n,y_validation_n)
    validation_mse = validation_rmse ** 2
    validation_mae = MAE(y_validation_pred_n,y_validation_n)
    
    validation_mse_list.append(validation_mse)
    validation_rmse_list.append(validation_rmse)
    validation_mae_list.append(validation_mae)


print("Average validation_mse after 20 interations:",sum(validation_mse_list)/len(validation_mse_list))
print("Average validation_rmse after 20 interations:",sum(validation_rmse_list)/len(validation_rmse_list))
print("Average validation_mae after 20 interations:",sum(validation_mae_list)/len(validation_mae_list))
# Out:
# Average validation_mse after 20 interations: 0.6072287497554765
# Average validation_rmse after 20 interations: 0.7761953882047175
# Average validation_mae after 20 interations: 0.6155233815918417

# %% [markdown]
# ##### 3.2 RF reg

# %%
from sklearn.ensemble import RandomForestRegressor
#Grid search of tuning hyperparameters
rf_reg = RandomForestRegressor(random_state = 42)
param_grid = {
          'n_estimators': [40,60,80],
          'max_depth': [None,5,10],
          'min_samples_split': [2, 4],
          'min_samples_leaf': [1, 2]
}
# Define the search object
search = GridSearchCV(rf_reg, param_grid, cv = 5,n_jobs = -1,error_score = 'raise',verbose=1)

# Fit the search object to the training set
search.fit(X_train, y_train)

#Show best parameters
print(f'rf_reg best parameters: {search.best_params_}')

best_rf = search.best_estimator_
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# rf_reg best parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 80}

# %%
#Cross_validation scores in training set
cv_score_calculor(best_rf)
# Out:
#             Score type  CV score on average
# 0     trainset_neg_MSE            -0.387619
# 1    trainset_neg_RMSE            -0.613269
# 2        train_neg_MAE            -0.447192
# 3  train_defalut_score             0.472624

# %%
#Plot learning curve in entire dataset 
lc_rf = learning_curve_plot(best_rf,model_name_s= type(best_rf).__name__)
lc_rf

# %%
#Model fit and show the results
best_rf_metrics,y_test_pred = model_builder(best_rf)
best_rf_metrics
# Out:
#   Evaluation criterion  Training Data  validtation Data  independent test Data
# 0                  MSE       0.039644          0.178780               0.633559
# 1                 RMSE       0.199109          0.422824               0.795964
# 2                  MAE       0.146913          0.345421               0.719165
# 3             R2_Score       0.957908          0.808983              -0.166940

# %%
validation_mse_list = []
validation_rmse_list = []
validation_mae_list =[]
for i in range(20):
    
    X_train_n, X_validation_n, y_train_n, y_validation_n = train_test_split(X_combined_norm, y_combined.values.ravel(), test_size=0.2)
    best_rf.fit(X_train_n,y_train_n)
    
    y_validation_pred_n = best_rf.predict(X_validation_n)
    validation_rmse = RMSE(y_validation_pred_n,y_validation_n)
    validation_mse = validation_rmse ** 2
    validation_mae = MAE(y_validation_pred_n,y_validation_n)
    
    validation_mse_list.append(validation_mse)
    validation_rmse_list.append(validation_rmse)
    validation_mae_list.append(validation_mae)


print("Average validation_mse after 20 interations:",sum(validation_mse_list)/len(validation_mse_list))
print("Average validation_rmse after 20 interations:",sum(validation_rmse_list)/len(validation_rmse_list))
print("Average validation_mae after 20 interations:",sum(validation_mae_list)/len(validation_mae_list))
# Out:
# Average validation_mse after 20 interations: 0.2922087069273897
# Average validation_rmse after 20 interations: 0.5285821315009019
# Average validation_mae after 20 interations: 0.3770312984191465

# %% [markdown]
# ##### 3.3 SVR

# %%
from sklearn.svm import SVR
svm_reg = SVR()
param_grid = {
    'C': [5,10,15,20],
    'epsilon': [0.03,0.06,0.1,0.15,0.2],  
}

search = GridSearchCV(svm_reg, param_grid, cv = 5,n_jobs = -1,error_score = 'raise',verbose=1)

search.fit(X_train, y_train)

print(f'svm_reg best parameters: {search.best_params_}')

best_svr = search.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# svm_reg best parameters: {'C': 15, 'epsilon': 0.2}

# %%
cv_score_calculor(best_svr)
# Out:
#             Score type  CV score on average
# 0     trainset_neg_MSE            -0.436884
# 1    trainset_neg_RMSE            -0.655488
# 2        train_neg_MAE            -0.467916
# 3  train_defalut_score             0.403786

# %%
lc_svr = learning_curve_plot(best_svr,model_name_s= type(best_svr).__name__)
lc_svr

# %%
best_svr_metrics,y_test_pred = model_builder(best_svr)
best_svr_metrics
# Out:
#   Evaluation criterion  Training Data  validtation Data  independent test Data
# 0                  MSE       0.153784          0.258810               0.858589
# 1                 RMSE       0.392153          0.508734               0.926601
# 2                  MAE       0.280654          0.402804               0.721625
# 3             R2_Score       0.836720          0.723475              -0.581419

# %%
validation_mse_list = []
validation_rmse_list = []
validation_mae_list =[]
for i in range(20):
    
    X_train_n, X_validation_n, y_train_n, y_validation_n = train_test_split(X_combined_norm, y_combined.values.ravel(), test_size=0.2)
    best_svr.fit(X_train_n,y_train_n)
    
    y_validation_pred_n = best_svr.predict(X_validation_n)
    validation_rmse = RMSE(y_validation_pred_n,y_validation_n)
    validation_mse = validation_rmse ** 2
    validation_mae = MAE(y_validation_pred_n,y_validation_n)
    
    validation_mse_list.append(validation_mse)
    validation_rmse_list.append(validation_rmse)
    validation_mae_list.append(validation_mae)


print("Average validation_mse after 20 interations:",sum(validation_mse_list)/len(validation_mse_list))
print("Average validation_rmse after 20 interations:",sum(validation_rmse_list)/len(validation_rmse_list))
print("Average validation_mae after 20 interations:",sum(validation_mae_list)/len(validation_mae_list))
# Out:
# Average validation_mse after 20 interations: 0.3092700733932847
# Average validation_rmse after 20 interations: 0.5504106406540281
# Average validation_mae after 20 interations: 0.3943593038894432

# %% [markdown]
# ##### 3.4 xgb

# %%
from xgboost import XGBRegressor
xgb_reg = XGBRegressor(subsample = 0.8,objective='reg:squarederror',random_state = 42)

param_grid = {
    'min_child_weight' : [2,3,4],
    'n_estimators': [110,115,120,125,130], 
    'max_depth': [5,10,15],     
}

search = GridSearchCV(xgb_reg, param_grid, cv = 5,n_jobs = -1,error_score = 'raise',verbose=1)

search.fit(X_train, y_train)

print(f'xgb best parameters: {search.best_params_}')

best_xgbr = search.best_estimator_
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# xgb best parameters: {'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 125}

# %%
cv_score_calculor(best_xgbr)
# Out:
#             Score type  CV score on average
# 0     trainset_neg_MSE            -0.347504
# 1    trainset_neg_RMSE            -0.573424
# 2        train_neg_MAE            -0.367280
# 3  train_defalut_score             0.574227

# %%
lc_xgbr = learning_curve_plot(best_xgbr,model_name_s= type(best_xgbr).__name__)
lc_xgbr

# %%
best_xgbr_metrics,y_test_pred = model_builder(best_xgbr)
best_xgbr_metrics
# Out:
#   Evaluation criterion  Training Data  validtation Data  independent test Data
# 0                  MSE       0.006580          0.118920               0.499339
# 1                 RMSE       0.081120          0.344848               0.706639
# 2                  MAE       0.060362          0.216977               0.554016
# 3             R2_Score       0.993013          0.872940               0.080278

# %%
validation_mse_list = []
validation_rmse_list = []
validation_mae_list =[]
for i in range(20):
    
    X_train_n, X_validation_n, y_train_n, y_validation_n = train_test_split(X_combined_norm, y_combined.values.ravel(), test_size=0.2)
    best_xgbr.fit(X_train_n,y_train_n)
    
    y_validation_pred_n = best_xgbr.predict(X_validation_n)
    validation_rmse = RMSE(y_validation_pred_n,y_validation_n)
    validation_mse = validation_rmse ** 2
    validation_mae = MAE(y_validation_pred_n,y_validation_n)
    
    validation_mse_list.append(validation_mse)
    validation_rmse_list.append(validation_rmse)
    validation_mae_list.append(validation_mae)


print("Average validation_mse after 20 interations:",sum(validation_mse_list)/len(validation_mse_list))
print("Average validation_rmse after 20 interations:",sum(validation_rmse_list)/len(validation_rmse_list))
print("Average validation_mae after 20 interations:",sum(validation_mae_list)/len(validation_mae_list))
# Out:
# Average validation_mse after 20 interations: 0.19235775401401065
# Average validation_rmse after 20 interations: 0.41781914767101574
# Average validation_mae after 20 interations: 0.25638453318075577

# %% [markdown]
# ##### 3.5 catboost_reg

# %%
from catboost import CatBoostRegressor
cat_reg = CatBoostRegressor(learning_rate= 0.25 ,bagging_temperature= 1,verbose = 0 ,random_state=42)
param_grid = {
    'iterations': [400,410,420],  
    'depth': [5,10], 
}


search = GridSearchCV(cat_reg, param_grid, cv = 5,n_jobs = -1,error_score = 'raise',verbose = 0)

search.fit(X_train, y_train)

print(f'cat_reg best parameters: {search.best_params_}')

best_catreg = search.best_estimator_
# Out:
# cat_reg best parameters: {'depth': 5, 'iterations': 410}

# %%
cv_score_calculor(best_catreg)
# Out:
#             Score type  CV score on average
# 0     trainset_neg_MSE            -0.300978
# 1    trainset_neg_RMSE            -0.547023
# 2        train_neg_MAE            -0.361018
# 3  train_defalut_score             0.588811

# %%
lc_catr = learning_curve_plot(best_catreg, model_name_s = type(best_catreg).__name__)
lc_catr

# %%
best_catreg_metrics,y_test_pred = model_builder(best_catreg)
best_catreg_metrics
# Out:
#   Evaluation criterion  Training Data  validtation Data  independent test Data
# 0                  MSE       0.006472          0.085497               0.429078
# 1                 RMSE       0.080451          0.292398               0.655040
# 2                  MAE       0.060469          0.200921               0.538922
# 3             R2_Score       0.993128          0.908651               0.209690

# %%
validation_mse_list = []
validation_rmse_list = []
validation_mae_list =[]
for i in range(20):
    
    X_train_n, X_validation_n, y_train_n, y_validation_n = train_test_split(X_combined_norm, y_combined.values.ravel(), test_size=0.2)
    best_catreg.fit(X_train_n,y_train_n)
    
    y_validation_pred_n = best_catreg.predict(X_validation_n)
    validation_rmse = RMSE(y_validation_pred_n,y_validation_n)
    validation_mse = validation_rmse ** 2
    validation_mae = MAE(y_validation_pred_n,y_validation_n)
    
    validation_mse_list.append(validation_mse)
    validation_rmse_list.append(validation_rmse)
    validation_mae_list.append(validation_mae)

print("Average validation_mse after 20 interations:",sum(validation_mse_list)/len(validation_mse_list))
print("Average validation_rmse after 20 interations:",sum(validation_rmse_list)/len(validation_rmse_list))
print("Average validation_mae after 20 interations:",sum(validation_mae_list)/len(validation_mae_list))
# Out:
# Average validation_mse after 20 interations: 0.15608746972011228
# Average validation_rmse after 20 interations: 0.37373107231332103
# Average validation_mae after 20 interations: 0.23248929378919603

# %% [markdown]
# #### 4.Modle explaination for CATBOOST

# %%
import shap
shap.initjs()
explainer = shap.TreeExplainer(best_catreg)
shap_values = explainer(X_combined_norm)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 24
plt.rcParams["axes.labelsize"] = 24
plt.rcParams["xtick.labelsize"] = 24
plt.rcParams["ytick.labelsize"] = 24

#Feature importance 
shap.plots.bar(shap_values,show = False)

plt.savefig(
    "output_figures/clustering.png",
    format='png',
    dpi=600,
    bbox_inches='tight'
)

# %%
#Summarize the effects of all the features
plt.rcParams["font.family"] = "Arial"         
plt.rcParams["font.size"] = 24                
plt.rcParams["axes.labelsize"] = 24            
plt.rcParams["xtick.labelsize"] = 24          
plt.rcParams["ytick.labelsize"] = 24  
plt.rcParams["figure.figsize"] = (24,16)
shap.summary_plot(shap_values,X_combined_norm, show=False) 
plt.savefig("output_figures/shap_summaryplot_comb.png", format='png', dpi= 600, bbox_inches='tight')

# %%
plt.rcParams["font.family"] = "Arial"         
plt.rcParams["font.size"] = 24                
plt.rcParams["axes.labelsize"] = 24            
plt.rcParams["xtick.labelsize"] = 24          
plt.rcParams["ytick.labelsize"] = 24  
i = 0
for name in X_combined_norm.columns:
  i= i+1
  plt.figure(figsize=(4,3))
  shap.dependence_plot(name,shap_values.values,X_combined,feature_names= X_combined_norm.columns,interaction_index=None,show=False)
  plt.savefig(f"output_figures/{i}.png", format='png',dpi = 600,bbox_inches='tight')  
  plt.show()

# %% [markdown]
# #### 5.Prediction for  passivators from Pubchem database

# %%
passivators_for_prediction = pd.read_csv("data/newpassivator_with_features.csv")
print("shape:",passivators_for_prediction.shape)
passivators_for_prediction.head(5)
# Out:
# shape: (700, 16)
#       CID                 IUPACName MolecularFormula  \
# 0  7812.0           4-chloroaniline          C6H6ClN
# 1  7423.0            3-nitroaniline         C6H6N2O2
# 2  9731.0           4-fluoroaniline           C6H6FN
# 3  7447.0  2-methoxy-5-nitroaniline         C7H8N2O3
# 4  7441.0   2-methyl-4-nitroaniline         C7H8N2O2
#
#                    IsomericSMILES  A_site  Conc(mg/ml)  H_Acceptors  H_Donors  \
# 0                C1=CC(=CC=C1N)Cl     0.0          1.0            1         1
# 1    C1=CC(=CC(=C1)[N+](=O)[O-])N     0.0          1.0            3         1
# 2                 C1=CC(=CC=C1N)F     0.0          1.0            1         1
# 3  COC1=C(C=C(C=C1)[N+](=O)[O-])N     0.0          1.0            4         1
# 4   CC1=C(C=CC(=C1)[N+](=O)[O-])N     0.0          1.0            3         1
#
#    Rot_bonds   Mol_Wt   TPSA    AvgIpc  Hydrogen  Oxide  Nitrogen  Halide
# 0          1  127.574  26.02  2.112066         6      0         1       1
# 1          2  138.126  69.16  2.131108         6      2         2       0
# 2          1  111.119  26.02  2.112066         6      0         1       1
# 3          4  168.152  78.39  2.222235         8      3         2       0
# 4          3  152.153  69.16  2.196466         8      2         2       0

# %%
X_prediction = passivators_for_prediction.iloc[:,4:]
X_prediction.head(20)
# Out:
#     A_site  Conc(mg/ml)  H_Acceptors  H_Donors  Rot_bonds   Mol_Wt    TPSA  \
# 0      0.0          1.0            1         1          1  127.574   26.02
# 1      0.0          1.0            3         1          2  138.126   69.16
# 2      0.0          1.0            1         1          1  111.119   26.02
# 3      0.0          1.0            4         1          4  168.152   78.39
# 4      0.0          1.0            3         1          3  152.153   69.16
# 5      0.0          1.0            3         1          3  171.221   60.16
# 6      0.0          1.0            4         1          6  196.206   78.39
# 7      0.0          1.0            3         1          2  178.235   38.49
# 8      0.0          1.0            3         1          2  172.571   69.16
# 9      0.0          1.0            3         1          2  225.191   60.16
# 10     0.0          1.0            1         1          1  470.817   26.02
# 11     0.0          1.0            3         1          4  166.180   69.16
# 12     0.0          1.0            2         1          7  144.214   37.30
# 13     0.0          1.0            3         2          3   90.078   57.53
# 14     0.0          1.0            3         2          2  137.138   63.32
# 15     0.0          1.0            5         4          4  170.120   97.99
# 16     0.0          1.0            5         2          2  167.120   87.49
# 17     0.0          1.0            4         3          1  156.097  103.02
# 18     0.0          1.0            3         2          1  189.170   70.16
# 19     0.0          1.0            3         1          5  179.219   50.19
#
#       AvgIpc  Hydrogen  Oxide  Nitrogen  Halide
# 0   2.112066         6      0         1       1
# 1   2.131108         6      2         2       0
# 2   2.112066         6      0         1       1
# 3   2.222235         8      3         2       0
# 4   2.196466         8      2         2       0
# 5   2.242309         9      2         1       0
# 6   2.416056        12      3         2       0
# 7   2.459172        14      1         2       0
# 8   2.183714         5      2         2       1
# 9   2.242309         6      2         1       3
# 10  2.112066         4      0         1       3
# 11  2.223818        10      2         2       0
# 12  2.432514        16      2         0       0
# 13  1.989466         6      3         0       0
# 14  2.258584         7      2         1       0
# 15  2.372085         6      5         0       0
# 16  2.331554         5      4         1       0
# 17  2.231935         4      4         2       0
# 18  2.457675         7      3         1       0
# 19  2.479078        13      2         1       0

# %%
X_prediction_norm = X_scaler.fit_transform(X_prediction)
X_prediction_norm = pd.DataFrame(X_prediction_norm,columns=X_prediction.columns)
X_prediction_norm.head(20)
# Out:
#     A_site  Conc(mg/ml)  H_Acceptors  H_Donors  Rot_bonds    Mol_Wt      TPSA  \
# 0      0.0          0.0     0.000000      0.25   0.052632  0.164373  0.071617
# 1      0.0          0.0     0.285714      0.25   0.105263  0.190062  0.416820
# 2      0.0          0.0     0.000000      0.25   0.052632  0.124313  0.071617
# 3      0.0          0.0     0.428571      0.25   0.210526  0.263160  0.490678
# 4      0.0          0.0     0.285714      0.25   0.157895  0.224211  0.416820
# 5      0.0          0.0     0.285714      0.25   0.157895  0.270632  0.344803
# 6      0.0          0.0     0.428571      0.25   0.315789  0.331458  0.490678
# 7      0.0          0.0     0.285714      0.25   0.105263  0.287707  0.171401
# 8      0.0          0.0     0.285714      0.25   0.105263  0.273918  0.416820
# 9      0.0          0.0     0.285714      0.25   0.105263  0.402022  0.344803
# 10     0.0          0.0     0.000000      0.25   0.052632  1.000000  0.071617
# 11     0.0          0.0     0.285714      0.25   0.210526  0.258359  0.416820
# 12     0.0          0.0     0.142857      0.25   0.368421  0.204883  0.161879
# 13     0.0          0.0     0.285714      0.50   0.157895  0.073089  0.323758
# 14     0.0          0.0     0.285714      0.50   0.105263  0.187657  0.370089
# 15     0.0          0.0     0.571429      1.00   0.210526  0.267951  0.647515
# 16     0.0          0.0     0.571429      0.50   0.105263  0.260648  0.563495
# 17     0.0          0.0     0.428571      0.75   0.052632  0.233812  0.687765
# 18     0.0          0.0     0.285714      0.50   0.052632  0.314329  0.424822
# 19     0.0          0.0     0.285714      0.25   0.263158  0.290103  0.265024
#
#       AvgIpc  Hydrogen  Oxide  Nitrogen  Halide
# 0   0.317127  0.147059  0.000      0.25    0.25
# 1   0.329928  0.147059  0.250      0.50    0.00
# 2   0.317127  0.147059  0.000      0.25    0.25
# 3   0.391190  0.205882  0.375      0.50    0.00
# 4   0.373866  0.205882  0.250      0.50    0.00
# 5   0.404685  0.235294  0.250      0.25    0.00
# 6   0.521488  0.323529  0.375      0.50    0.00
# 7   0.550474  0.382353  0.125      0.50    0.00
# 8   0.365293  0.117647  0.250      0.50    0.25
# 9   0.404685  0.147059  0.250      0.25    0.75
# 10  0.317127  0.088235  0.000      0.25    0.75
# 11  0.392254  0.264706  0.250      0.50    0.00
# 12  0.532553  0.441176  0.250      0.00    0.00
# 13  0.234707  0.147059  0.375      0.00    0.00
# 14  0.415626  0.176471  0.250      0.25    0.00
# 15  0.491928  0.147059  0.625      0.00    0.00
# 16  0.464681  0.117647  0.500      0.25    0.00
# 17  0.397711  0.088235  0.500      0.50    0.00
# 18  0.549468  0.176471  0.375      0.25    0.00
# 19  0.563856  0.352941  0.250      0.25    0.00

# %%
X_prediction = passivators_for_prediction.iloc[:,4:]
X_prediction.head()
# Out:
#    A_site  Conc(mg/ml)  H_Acceptors  H_Donors  Rot_bonds   Mol_Wt   TPSA  \
# 0     0.0          1.0            1         1          1  127.574  26.02
# 1     0.0          1.0            3         1          2  138.126  69.16
# 2     0.0          1.0            1         1          1  111.119  26.02
# 3     0.0          1.0            4         1          4  168.152  78.39
# 4     0.0          1.0            3         1          3  152.153  69.16
#
#      AvgIpc  Hydrogen  Oxide  Nitrogen  Halide
# 0  2.112066         6      0         1       1
# 1  2.131108         6      2         2       0
# 2  2.112066         6      0         1       1
# 3  2.222235         8      3         2       0
# 4  2.196466         8      2         2       0

# %%
y_prediction = best_catreg.predict(X_prediction_norm)

# %%
prediction_res = passivators_for_prediction.iloc[:,:6]
prediction_res["EQE prediciton enhancement ratio"] = y_prediction
prediction_res_sorted = prediction_res.sort_values(by="CID",ascending=True)
#CsPbBr3
prediction_res_1_sorted = prediction_res_sorted[prediction_res_sorted['A_site'] == 1]
print(prediction_res_1_sorted.shape)
prediction_res_1_sorted.head(20)
# Out:
# (350, 7)
#        CID                              IUPACName MolecularFormula  \
# 513  240.0                           benzaldehyde            C7H6O
# 583  240.0                           benzaldehyde            C7H6O
# 443  240.0                           benzaldehyde            C7H6O
# 373  240.0                           benzaldehyde            C7H6O
# 653  240.0                           benzaldehyde            C7H6O
# 410  255.0  bis(4-nitrophenyl) hydrogen phosphate       C12H9N2O8P
# 620  255.0  bis(4-nitrophenyl) hydrogen phosphate       C12H9N2O8P
# 690  255.0  bis(4-nitrophenyl) hydrogen phosphate       C12H9N2O8P
# 550  255.0  bis(4-nitrophenyl) hydrogen phosphate       C12H9N2O8P
# 480  255.0  bis(4-nitrophenyl) hydrogen phosphate       C12H9N2O8P
# 365  370.0           3,4,5-trihydroxybenzoic acid           C7H6O5
# 505  370.0           3,4,5-trihydroxybenzoic acid           C7H6O5
# 435  370.0           3,4,5-trihydroxybenzoic acid           C7H6O5
# 645  370.0           3,4,5-trihydroxybenzoic acid           C7H6O5
# 575  370.0           3,4,5-trihydroxybenzoic acid           C7H6O5
# 432  379.0                          octanoic acid          C8H16O2
# 362  379.0                          octanoic acid          C8H16O2
# 642  379.0                          octanoic acid          C8H16O2
# 502  379.0                          octanoic acid          C8H16O2
# 572  379.0                          octanoic acid          C8H16O2
#
#                                         IsomericSMILES  A_site  Conc(mg/ml)  \
# 513                                   C1=CC=C(C=C1)C=O     1.0          4.0
# 583                                   C1=CC=C(C=C1)C=O     1.0          6.0
# 443                                   C1=CC=C(C=C1)C=O     1.0          2.0
# 373                                   C1=CC=C(C=C1)C=O     1.0          1.0
# 653                                   C1=CC=C(C=C1)C=O     1.0          8.0
# 410  C1=CC(=CC=C1[N+](=O)[O-])OP(=O)(O)OC2=CC=C(C=C...     1.0          1.0
# 620  C1=CC(=CC=C1[N+](=O)[O-])OP(=O)(O)OC2=CC=C(C=C...     1.0          6.0
# 690  C1=CC(=CC=C1[N+](=O)[O-])OP(=O)(O)OC2=CC=C(C=C...     1.0          8.0
# 550  C1=CC(=CC=C1[N+](=O)[O-])OP(=O)(O)OC2=CC=C(C=C...     1.0          4.0
# 480  C1=CC(=CC=C1[N+](=O)[O-])OP(=O)(O)OC2=CC=C(C=C...     1.0          2.0
# 365                         C1=C(C=C(C(=C1O)O)O)C(=O)O     1.0          1.0
# 505                         C1=C(C=C(C(=C1O)O)O)C(=O)O     1.0          4.0
# 435                         C1=C(C=C(C(=C1O)O)O)C(=O)O     1.0          2.0
# 645                         C1=C(C=C(C(=C1O)O)O)C(=O)O     1.0          8.0
# 575                         C1=C(C=C(C(=C1O)O)O)C(=O)O     1.0          6.0
# 432                                      CCCCCCCC(=O)O     1.0          2.0
# 362                                      CCCCCCCC(=O)O     1.0          1.0
# 642                                      CCCCCCCC(=O)O     1.0          8.0
# 502                                      CCCCCCCC(=O)O     1.0          4.0
# 572                                      CCCCCCCC(=O)O     1.0          6.0
#
#      EQE prediciton enhancement ratio
# 513                          1.820800
# 583                          2.127199
# 443                          1.698863
# 373                          1.959163
# 653                          2.127199
# 410                          1.908454
# 620                          1.768127
# 690                          1.768127
# 550                          1.649478
# 480                          1.414662
# 365                          2.089930
# 505                          2.445456
# 435                          2.073843
# 645                          2.454671
# 575                          2.454671
# 432                          1.968104
# 362                          2.938172
# 642                          2.387261
# 502                          2.317087
# 572                          2.387261

# %%
prediction_res_1_average = prediction_res_1_sorted.groupby(['CID','IUPACName','MolecularFormula','IsomericSMILES','A_site'],as_index=False).agg({'EQE prediciton enhancement ratio':'mean'})
prediction_res_1_average = prediction_res_1_average.rename(columns={'EQE prediciton enhancement ratio':'average pred EQE enhancement ratio'})
prediction_res_1_average.head(20)
# Out:
#        CID                                     IUPACName MolecularFormula  \
# 0    240.0                                  benzaldehyde            C7H6O
# 1    255.0         bis(4-nitrophenyl) hydrogen phosphate       C12H9N2O8P
# 2    370.0                  3,4,5-trihydroxybenzoic acid           C7H6O5
# 3    379.0                                 octanoic acid          C8H16O2
# 4    612.0                       2-hydroxypropanoic acid           C3H6O3
# 5    654.0                    diethyl hydrogen phosphate         C4H11O4P
# 6    668.0  (3-hydroxy-2-oxopropyl) dihydrogen phosphate          C3H7O6P
# 7    936.0                        pyridine-3-carboxamide          C6H6N2O
# 8    967.0     2,4-dioxo-1H-pyrimidine-6-carboxylic acid         C5H4N2O4
# 9    978.0                           4-aminobenzoic acid          C7H7NO2
# 10   980.0                                 4-nitrophenol          C6H5NO3
# 11   985.0                             hexadecanoic acid         C16H32O2
# 12  1015.0             2-aminoethyl dihydrogen phosphate         C2H8NO4P
# 13  1066.0                pyridine-2,3-dicarboxylic acid          C7H5NO4
# 14  1176.0                                          urea           CH4N2O
# 15  1493.0                             2,4-dinitrophenol         C6H4N2O5
# 16  1678.0                         3-nitropropanoic acid          C3H5NO4
# 17  3442.0             5-butylpyridine-2-carboxylic acid        C10H13NO2
# 18  3845.0          4-oxo-1H-quinoline-2-carboxylic acid         C10H7NO3
# 19  5570.0           1-methylpyridin-1-ium-3-carboxylate          C7H7NO2
#
#                                        IsomericSMILES  A_site  \
# 0                                    C1=CC=C(C=C1)C=O     1.0
# 1   C1=CC(=CC=C1[N+](=O)[O-])OP(=O)(O)OC2=CC=C(C=C...     1.0
# 2                          C1=C(C=C(C(=C1O)O)O)C(=O)O     1.0
# 3                                       CCCCCCCC(=O)O     1.0
# 4                                         CC(C(=O)O)O     1.0
# 5                                      CCOP(=O)(O)OCC     1.0
# 6                                C(C(=O)COP(=O)(O)O)O     1.0
# 7                                 C1=CC(=CN=C1)C(=O)N     1.0
# 8                             C1=C(NC(=O)NC1=O)C(=O)O     1.0
# 9                                C1=CC(=CC=C1C(=O)O)N     1.0
# 10                         C1=CC(=CC=C1[N+](=O)[O-])O     1.0
# 11                              CCCCCCCCCCCCCCCC(=O)O     1.0
# 12                                    C(COP(=O)(O)O)N     1.0
# 13                        C1=CC(=C(N=C1)C(=O)O)C(=O)O     1.0
# 14                                          C(=O)(N)N     1.0
# 15           C1=CC(=C(C=C1[N+](=O)[O-])[N+](=O)[O-])O     1.0
# 16                             C(C[N+](=O)[O-])C(=O)O     1.0
# 17                            CCCCC1=CN=C(C=C1)C(=O)O     1.0
# 18                   C1=CC=C2C(=C1)C(=O)C=C(N2)C(=O)O     1.0
# 19                         C[N+]1=CC=CC(=C1)C(=O)[O-]     1.0
#
#     average pred EQE enhancement ratio
# 0                             1.946645
# 1                             1.701769
# 2                             2.303714
# 3                             2.399577
# 4                             3.752916
# 5                             2.546216
# 6                             2.076781
# 7                             3.423775
# 8                             2.066821
# 9                             2.611709
# 10                            2.449889
# 11                            2.029067
# 12                            2.053915
# 13                            1.885582
# 14                            2.920401
# 15                            2.105319
# 16                            2.741399
# 17                            2.736297
# 18                            1.945455
# 19                            2.428195

# %%
#top 10
prediction_res_1_average.sort_values(by='average pred EQE enhancement ratio',ascending=False).head(10)
# Out:
#         CID                          IUPACName MolecularFormula  \
# 4     612.0            2-hydroxypropanoic acid           C3H6O3
# 7     936.0             pyridine-3-carboxamide          C6H6N2O
# 43  13134.0        dimethyl hydrogen phosphate          C2H7O4P
# 14   1176.0                               urea           CH4N2O
# 40  12307.0                     propyl nitrate          C3H7NO3
# 37   9731.0                    4-fluoroaniline           C6H6FN
# 16   1678.0              3-nitropropanoic acid          C3H5NO4
# 17   3442.0  5-butylpyridine-2-carboxylic acid        C10H13NO2
# 31   7812.0                    4-chloroaniline          C6H6ClN
# 34   8431.0     ethyl piperazine-1-carboxylate        C7H14N2O2
#
#              IsomericSMILES  A_site  average pred EQE enhancement ratio
# 4               CC(C(=O)O)O     1.0                            3.752916
# 7       C1=CC(=CN=C1)C(=O)N     1.0                            3.423775
# 43             COP(=O)(O)OC     1.0                            3.311908
# 14                C(=O)(N)N     1.0                            2.920401
# 40         CCCO[N+](=O)[O-]     1.0                            2.854169
# 37          C1=CC(=CC=C1N)F     1.0                            2.771568
# 16   C(C[N+](=O)[O-])C(=O)O     1.0                            2.741399
# 17  CCCCC1=CN=C(C=C1)C(=O)O     1.0                            2.736297
# 31         C1=CC(=CC=C1N)Cl     1.0                            2.684386
# 34         CCOC(=O)N1CCNCC1     1.0                            2.669454

# %%
#last 10
prediction_res_1_average.sort_values(by='average pred EQE enhancement ratio',ascending=True).head(10)
# Out:
#            CID                                          IUPACName  \
# 33      8330.0                 1,2,4,5-tetrachloro-3-nitrobenzene
# 36      9395.0                  diethyl (4-nitrophenyl) phosphate
# 1        255.0              bis(4-nitrophenyl) hydrogen phosphate
# 32      7873.0               diethoxyphosphoryl diethyl phosphate
# 66   4190003.0                           benzenesulfinyl chloride
# 41     12495.0                              1-iodo-4-nitrobenzene
# 22      7369.0                           benzenesulfonyl chloride
# 69  12669616.0                   4-fluorobenzenesulfinyl chloride
# 65    222556.0                               2,4,6-triiodoaniline
# 58     75498.0  5-(1,3-dioxo-2-benzofuran-5-carbonyl)-2-benzof...
#
#    MolecularFormula                                     IsomericSMILES  \
# 33        C6HCl4NO2            C1=C(C(=C(C(=C1Cl)Cl)[N+](=O)[O-])Cl)Cl
# 36       C10H14NO6P            CCOP(=O)(OCC)OC1=CC=C(C=C1)[N+](=O)[O-]
# 1        C12H9N2O8P  C1=CC(=CC=C1[N+](=O)[O-])OP(=O)(O)OC2=CC=C(C=C...
# 32        C8H20O7P2                        CCOP(=O)(OCC)OP(=O)(OCC)OCC
# 66         C6H5ClOS                               C1=CC=C(C=C1)S(=O)Cl
# 41         C6H4INO2                         C1=CC(=CC=C1[N+](=O)[O-])I
# 22        C6H5ClO2S                           C1=CC=C(C=C1)S(=O)(=O)Cl
# 69        C6H4ClFOS                              C1=CC(=CC=C1F)S(=O)Cl
# 65          C6H4I3N                              C1=C(C=C(C(=C1I)N)I)I
# 58          C17H6O7  C1=CC2=C(C=C1C(=O)C3=CC4=C(C=C3)C(=O)OC4=O)C(=...
#
#     A_site  average pred EQE enhancement ratio
# 33     1.0                            1.579576
# 36     1.0                            1.698010
# 1      1.0                            1.701769
# 32     1.0                            1.764019
# 66     1.0                            1.768253
# 41     1.0                            1.774494
# 22     1.0                            1.787469
# 69     1.0                            1.789658
# 65     1.0                            1.790882
# 58     1.0                            1.881145

# %%
#LA  612 no.1
LA_pred = prediction_res[(prediction_res['CID'] == 612) & (prediction_res['A_site'] == 1)]
LA_pred
# Out:
#        CID                IUPACName MolecularFormula IsomericSMILES  A_site  \
# 363  612.0  2-hydroxypropanoic acid           C3H6O3    CC(C(=O)O)O     1.0
# 433  612.0  2-hydroxypropanoic acid           C3H6O3    CC(C(=O)O)O     1.0
# 503  612.0  2-hydroxypropanoic acid           C3H6O3    CC(C(=O)O)O     1.0
# 573  612.0  2-hydroxypropanoic acid           C3H6O3    CC(C(=O)O)O     1.0
# 643  612.0  2-hydroxypropanoic acid           C3H6O3    CC(C(=O)O)O     1.0
#
#      Conc(mg/ml)  EQE prediciton enhancement ratio
# 363          1.0                          3.193122
# 433          2.0                          3.337670
# 503          4.0                          3.808153
# 573          6.0                          4.212819
# 643          8.0                          4.212819

# %%
#LA  mean
LA_pred['EQE prediciton enhancement ratio'].mean()
# Out:
# 3.752916328639747

# %%
#P3C  936 no.2
P3C_pred = prediction_res[(prediction_res['CID'] == 936) & (prediction_res['A_site'] == 1)]
P3C_pred
# Out:
#        CID               IUPACName MolecularFormula       IsomericSMILES  \
# 372  936.0  pyridine-3-carboxamide          C6H6N2O  C1=CC(=CN=C1)C(=O)N
# 442  936.0  pyridine-3-carboxamide          C6H6N2O  C1=CC(=CN=C1)C(=O)N
# 512  936.0  pyridine-3-carboxamide          C6H6N2O  C1=CC(=CN=C1)C(=O)N
# 582  936.0  pyridine-3-carboxamide          C6H6N2O  C1=CC(=CN=C1)C(=O)N
# 652  936.0  pyridine-3-carboxamide          C6H6N2O  C1=CC(=CN=C1)C(=O)N
#
#      A_site  Conc(mg/ml)  EQE prediciton enhancement ratio
# 372     1.0          1.0                          2.875758
# 442     1.0          2.0                          3.106744
# 512     1.0          4.0                          3.515876
# 582     1.0          6.0                          3.810249
# 652     1.0          8.0                          3.810249

# %%
#P3C mean
P3C_pred['EQE prediciton enhancement ratio'].mean()
# Out:
# 3.423775344427509

# %%
#DP 13134 no.3
DP_pred = prediction_res[(prediction_res['CID'] == 13134) & (prediction_res['A_site'] == 1)]
DP_pred
# Out:
#          CID                    IUPACName MolecularFormula IsomericSMILES  \
# 403  13134.0  dimethyl hydrogen phosphate          C2H7O4P   COP(=O)(O)OC
# 473  13134.0  dimethyl hydrogen phosphate          C2H7O4P   COP(=O)(O)OC
# 543  13134.0  dimethyl hydrogen phosphate          C2H7O4P   COP(=O)(O)OC
# 613  13134.0  dimethyl hydrogen phosphate          C2H7O4P   COP(=O)(O)OC
# 683  13134.0  dimethyl hydrogen phosphate          C2H7O4P   COP(=O)(O)OC
#
#      A_site  Conc(mg/ml)  EQE prediciton enhancement ratio
# 403     1.0          1.0                          3.178453
# 473     1.0          2.0                          2.804449
# 543     1.0          4.0                          3.237823
# 613     1.0          6.0                          3.669407
# 683     1.0          8.0                          3.669407

# %%
#DP mean 
DP_pred['EQE prediciton enhancement ratio'].mean()
# Out:
# 3.3119079150123234

# %%
#BC test suzhou
BC_pred = prediction_res[(prediction_res['CID'] == 7369) & (prediction_res['A_site'] == 1)]
BC_pred
# Out:
#         CID                 IUPACName MolecularFormula  \
# 416  7369.0  benzenesulfonyl chloride        C6H5ClO2S
# 486  7369.0  benzenesulfonyl chloride        C6H5ClO2S
# 556  7369.0  benzenesulfonyl chloride        C6H5ClO2S
# 626  7369.0  benzenesulfonyl chloride        C6H5ClO2S
# 696  7369.0  benzenesulfonyl chloride        C6H5ClO2S
#
#                IsomericSMILES  A_site  Conc(mg/ml)  \
# 416  C1=CC=C(C=C1)S(=O)(=O)Cl     1.0          1.0
# 486  C1=CC=C(C=C1)S(=O)(=O)Cl     1.0          2.0
# 556  C1=CC=C(C=C1)S(=O)(=O)Cl     1.0          4.0
# 626  C1=CC=C(C=C1)S(=O)(=O)Cl     1.0          6.0
# 696  C1=CC=C(C=C1)S(=O)(=O)Cl     1.0          8.0
#
#      EQE prediciton enhancement ratio
# 416                          2.047037
# 486                          1.500180
# 556                          1.601710
# 626                          1.894209
# 696                          1.894209

# %%
#BC mean 7369
BC_pred['EQE prediciton enhancement ratio'].mean()
# Out:
# 1.787469211131728

# %%
#last 8330
TE_pred = prediction_res[(prediction_res['CID'] == 8330) & (prediction_res['A_site'] == 1)]
TE_pred
# Out:
#         CID                           IUPACName MolecularFormula  \
# 397  8330.0  1,2,4,5-tetrachloro-3-nitrobenzene        C6HCl4NO2
# 467  8330.0  1,2,4,5-tetrachloro-3-nitrobenzene        C6HCl4NO2
# 537  8330.0  1,2,4,5-tetrachloro-3-nitrobenzene        C6HCl4NO2
# 607  8330.0  1,2,4,5-tetrachloro-3-nitrobenzene        C6HCl4NO2
# 677  8330.0  1,2,4,5-tetrachloro-3-nitrobenzene        C6HCl4NO2
#
#                               IsomericSMILES  A_site  Conc(mg/ml)  \
# 397  C1=C(C(=C(C(=C1Cl)Cl)[N+](=O)[O-])Cl)Cl     1.0          1.0
# 467  C1=C(C(=C(C(=C1Cl)Cl)[N+](=O)[O-])Cl)Cl     1.0          2.0
# 537  C1=C(C(=C(C(=C1Cl)Cl)[N+](=O)[O-])Cl)Cl     1.0          4.0
# 607  C1=C(C(=C(C(=C1Cl)Cl)[N+](=O)[O-])Cl)Cl     1.0          6.0
# 677  C1=C(C(=C(C(=C1Cl)Cl)[N+](=O)[O-])Cl)Cl     1.0          8.0
#
#      EQE prediciton enhancement ratio
# 397                          1.767503
# 467                          1.508444
# 537                          1.449202
# 607                          1.586366
# 677                          1.586366

# %%
TE_pred['EQE prediciton enhancement ratio'].mean()
# Out:
# 1.5795759919587147
